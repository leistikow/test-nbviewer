# %% [markdown]
# Basic Interactor Demo
# ---------------------
#
# This demo shows off an interactive visualization using [Bokeh](https://bokeh.pydata.org) for plotting, and Ipython interactors for widgets. The demo runs entirely inside the Ipython notebook, with no Bokeh server required.
#
# The dropdown offers a choice of trig functions to plot, and the sliders control the frequency, amplitude, and phase.
#
# To run, click on, `Cell->Run All` in the top menu, then scroll to the bottom and move the sliders.

# %%
from ipywidgets import interact
import numpy as np

from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7d4fb1d1-e1b3-45fd-8ae1-3c52a39c4871">Loading BokehJS ...</span>
#     </div>

# %%
x = np.linspace(0, 2*np.pi, 2000)
y = np.sin(x)

# %%
p = figure(title="simple line example", plot_height=300, plot_width=600, y_range=(-5,5))
r = p.line(x, y, color="#2222aa", line_width=3)

# %%
def update(f, w=1, A=1, phi=0):
    if   f == "sin": func = np.sin
    elif f == "cos": func = np.cos
    elif f == "tan": func = np.tan
    r.data_source.data['y'] = A * func(w * x + phi)
    push_notebook()

# %%
show(p, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="65d7a0aa-fc8e-4e0d-97e3-56fa48f17206"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("65d7a0aa-fc8e-4e0d-97e3-56fa48f17206");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("2a0efda3-4262-495f-a9ab-0d239b163f8d", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("65d7a0aa-fc8e-4e0d-97e3-56fa48f17206");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '65d7a0aa-fc8e-4e0d-97e3-56fa48f17206' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"aba7cd08-4e28-4973-bb42-50243a3acda1":{"roots":{"references":[{"attributes":{"formatter":{"id":"409ef7fe-907e-4532-b5cc-db31b6be5a13","type":"BasicTickFormatter"},"plot":{"id":"c93b5f48-6729-4d13-9731-e83f68bed251","subtype":"Figure","type":"Plot"},"ticker":{"id":"e55d5bdc-50ce-4120-9299-aa880c88b062","type":"BasicTicker"}},"id":"7663c7c4-c9d7-4e34-921e-1d956da26e22","type":"LinearAxis"},{"attributes":{},"id":"e55d5bdc-50ce-4120-9299-aa880c88b062","type":"BasicTicker"},{"attributes":{"plot":{"id":"c93b5f48-6729-4d13-9731-e83f68bed251","subtype":"Figure","type":"Plot"},"ticker":{"id":"e55d5bdc-50ce-4120-9299-aa880c88b062","type":"BasicTicker"}},"id":"3ceb64d9-6302-4e4d-be00-31bcb0fcf4a1","type":"Grid"},{"attributes":{"formatter":{"id":"c104e0c4-8288-4a55-afdc-f6ac8634818a","type":"BasicTickFormatter"},"plot":{"id":"c93b5f48-6729-4d13-9731-e83f68bed251","subtype":"Figure","type":"Plot"},"ticker":{"id":"12afd635-7a9b-4711-b1cb-36cccf333559","type":"BasicTicker"}},"id":"c4363661-08bc-437a-bafa-3eba979ffd4d","type":"LinearAxis"},{"attributes":{},"id":"409ef7fe-907e-4532-b5cc-db31b6be5a13","type":"BasicTickFormatter"},{"attributes":{},"id":"12afd635-7a9b-4711-b1cb-36cccf333559","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"c93b5f48-6729-4d13-9731-e83f68bed251","subtype":"Figure","type":"Plot"},"ticker":{"id":"12afd635-7a9b-4711-b1cb-36cccf333559","type":"BasicTicker"}},"id":"531bb045-61d4-41db-9c14-7c1cb12e6905","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[2000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[2000]}}},"id":"f7cb0149-e898-4d4e-94c9-cf4da60aed04","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"656e28e6-0eaf-4471-977a-5eedbb7de422","type":"Line"},{"attributes":{"below":[{"id":"7663c7c4-c9d7-4e34-921e-1d956da26e22","type":"LinearAxis"}],"left":[{"id":"c4363661-08bc-437a-bafa-3eba979ffd4d","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"7663c7c4-c9d7-4e34-921e-1d956da26e22","type":"LinearAxis"},{"id":"3ceb64d9-6302-4e4d-be00-31bcb0fcf4a1","type":"Grid"},{"id":"c4363661-08bc-437a-bafa-3eba979ffd4d","type":"LinearAxis"},{"id":"531bb045-61d4-41db-9c14-7c1cb12e6905","type":"Grid"},{"id":"8eefcd69-4875-416c-9678-35862bbbc364","type":"BoxAnnotation"},{"id":"82c3e2df-4921-48d8-b4dc-19291ee85804","type":"GlyphRenderer"}],"title":{"id":"7fa593ef-936d-4fa3-87d9-c2e4170ac8bf","type":"Title"},"tool_events":{"id":"74291522-24ae-4cba-ad16-316b75eafc20","type":"ToolEvents"},"toolbar":{"id":"cc1217f5-f976-446f-84ab-12531c1360ea","type":"Toolbar"},"x_range":{"id":"ddb0dff2-86e4-44fd-89aa-c3622cbac34c","type":"DataRange1d"},"x_scale":{"id":"1d5d63e3-cfa6-4d71-bc84-05a78f2d421c","type":"LinearScale"},"y_range":{"id":"fae3b5ed-6f96-4294-9249-128ab379e89f","type":"Range1d"},"y_scale":{"id":"5508f15a-f7a1-491b-bc61-0cbbbf8982a0","type":"LinearScale"}},"id":"c93b5f48-6729-4d13-9731-e83f68bed251","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":"simple line example"},"id":"7fa593ef-936d-4fa3-87d9-c2e4170ac8bf","type":"Title"},{"attributes":{"plot":{"id":"c93b5f48-6729-4d13-9731-e83f68bed251","subtype":"Figure","type":"Plot"}},"id":"c1d1190c-fcfd-4ebd-849f-6682fec7d1c1","type":"PanTool"},{"attributes":{"callback":null},"id":"ddb0dff2-86e4-44fd-89aa-c3622cbac34c","type":"DataRange1d"},{"attributes":{"data_source":{"id":"f7cb0149-e898-4d4e-94c9-cf4da60aed04","type":"ColumnDataSource"},"glyph":{"id":"286bf86c-0faf-4400-ada5-ae86c88a0252","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"656e28e6-0eaf-4471-977a-5eedbb7de422","type":"Line"},"selection_glyph":null},"id":"82c3e2df-4921-48d8-b4dc-19291ee85804","type":"GlyphRenderer"},{"attributes":{},"id":"c104e0c4-8288-4a55-afdc-f6ac8634818a","type":"BasicTickFormatter"},{"attributes" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[7]</strong>&gt;</code></p>

# %%
interact(update, f=["sin", "cos", "tan"], w=(0,100), A=(1,5), phi=(0, 20, 0.1))

# %%
from bokeh.io import output_file, show
from bokeh.layouts import widgetbox
from bokeh.models.widgets import Button

output_file("button.html")

button = Button(label="Foo", button_type="success")

show(widgetbox(button))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6c523a94-6179-42a4-b8cd-866ebc32b83f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6c523a94-6179-42a4-b8cd-866ebc32b83f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6c523a94-6179-42a4-b8cd-866ebc32b83f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6c523a94-6179-42a4-b8cd-866ebc32b83f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f319f900-df68-450f-ac6b-ae4baaccb4dc":{"roots":{"references":[{"attributes":{"children":[{"id":"19add0f6-9439-46d5-93a0-fea5cdb9b2aa","type":"Button"}]},"id":"0f8af536-3978-42c9-af18-e5fe98f21f5b","type":"WidgetBox"},{"attributes":{"button_type":"success","callback":null,"icon":null,"label":"Foo"},"id":"19add0f6-9439-46d5-93a0-fea5cdb9b2aa","type":"Button"}],"root_ids":["0f8af536-3978-42c9-af18-e5fe98f21f5b"]},"title":"Bokeh Application","version":"0.12.6"}};
#             var render_items = [{"docid":"f319f900-df68-450f-ac6b-ae4baaccb4dc","elementid":"6c523a94-6179-42a4-b8cd-866ebc32b83f","modelid":"0f8af536-3978-42c9-af18-e5fe98f21f5b"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#           };
#           if (document.readyState != "loading") fn();
#           else document.addEventListener("DOMContentLoaded", fn);
#         })();
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#
#       if ((window.Bokeh !== undefined) || (force === true)) {
#         for (var i = 0; i < inline_js.length; i++) {
#           inline_js[i](window.Bokeh);
#         }if (force === true) {
#           display_loaded();
#         }} else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(run_inline_js, 100);
#       } else if (!window._bokeh_failed_load) {
#         console.log("Bokeh: BokehJS failed to load within specified timeout.");
#         window._bokeh_failed_load = true;
#       } else if (force !== true) {
#         var cell = $(document.getElementById("6c523a94-6179-42a4-b8cd-866ebc32b83f")).parents('.cell').data().cell;
#         cell.output_area.append_execute_result(NB_LOAD_WARNING)
#       }
#
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(this));
# </script>

# %%
import numpy as np
from bokeh.io import show, output_file
from bokeh.plotting import figure
from bokeh import events
from bokeh.models import CustomJS, Div, Button
from bokeh.layouts import column, row

def display_event(div, attributes=[], style = 'float:left;clear:left;font_size=0.5pt'):
    "Build a suitable CustomJS to display the current event in the div model."
    return CustomJS(args=dict(div=div), code="""
        var attrs = %s; var args = [];
        for (var i=0; i<attrs.length; i++ ) {
            args.push(attrs[i] + '=' + Number(cb_obj[attrs[i]]).toFixed(2));
        }
        var line = "<span style=%r><b>" + cb_obj.event_name + "</b>(" + args.join(", ") + ")</span>\\n";
        var text = div.text.concat(line);
        var lines = text.split("\\n")
        if ( lines.length > 35 ) { lines.shift(); }
        div.text = lines.join("\\n");
    """ % (attributes, style))

x = np.random.random(size=4000) * 100
y = np.random.random(size=4000) * 100
radii = np.random.random(size=4000) * 1.5
colors = ["#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(50+2*x, 30+2*y)]

p = figure(tools="pan,wheel_zoom,zoom_in,zoom_out,reset")
p.scatter(x, y, radius=np.random.random(size=4000) * 1.5,
          fill_color=colors, fill_alpha=0.6, line_color=None)

div = Div(width=1000)
button = Button(label="Button", button_type="success")
layout = column(button, row(p, div))

## Events with no attributes
button.js_on_event(events.ButtonClick, display_event(div)) # Button click
p.js_on_event(events.LODStart, display_event(div))         # Start of LOD display
p.js_on_event(events.LODEnd, display_event(div))           # End of LOD display

## Events with attributes
point_attributes = ['x','y','sx','sy']                     # Point events
wheel_attributes = point_attributes+['delta']              # Mouse wheel event
pan_attributes = point_attributes + ['delta_x', 'delta_y'] # Pan event
pinch_attributes = point_attributes + ['scale']            # Pinch event

point_events =  [events.Tap, events.DoubleTap, events.Press,
                 events.MouseMove, events.MouseEnter, events.MouseLeave,
                 events.PanStart, events.PanEnd, events.PinchStart, events.PinchEnd]

for event in point_events:
    p.js_on_event(event,display_event(div, attributes=point_attributes))

p.js_on_event(events.MouseWheel, display_event(div,attributes=wheel_attributes))
p.js_on_event(events.Pan,        display_event(div, attributes=pan_attributes))
p.js_on_event(events.Pinch,      display_event(div, attributes=pinch_attributes))

output_file("js_events.html", title="JS Events Example")
show(layout)
Button
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7b5e400b-1ae4-40c1-9b39-01b0c95e472d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("7b5e400b-1ae4-40c1-9b39-01b0c95e472d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7b5e400b-1ae4-40c1-9b39-01b0c95e472d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7b5e400b-1ae4-40c1-9b39-01b0c95e472d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4474a17b-ce49-43c7-b47d-202fbd4545c9":{"roots":{"references":[{"attributes":{"args":{"div":{"id":"491e9f36-dcba-4cf2-a022-385b7f408a8a","type":"Div"}},"code":"\n        var attrs = []; var args = [];\n        for (var i=0; i<attrs.length; i++ ) {\n            args.push(attrs[i] + '=' + Number(cb_obj[attrs[i]]).toFixed(2));\n        }\n        var line = \"<span style='float:left;clear:left;font_size=0.5pt'><b>\" + cb_obj.event_name + \"</b>(\" + args.join(\", \") + \")</span>\\n\";\n        var text = div.text.concat(line);\n        var lines = text.split(\"\\n\")\n        if ( lines.length > 35 ) { lines.shift(); }\n        div.text = lines.join(\"\\n\");\n    "},"id":"0c74e042-8abe-42dd-9086-241e8e3d2d32","type":"CustomJS"},{"attributes":{},"id":"a3455891-ec33-4a9b-922a-3f55f794ffae","type":"ToolEvents"},{"attributes":{"args":{"div":{"id":"491e9f36-dcba-4cf2-a022-385b7f408a8a","type":"Div"}},"code":"\n        var attrs = []; var args = [];\n        for (var i=0; i<attrs.length; i++ ) {\n            args.push(attrs[i] + '=' + Number(cb_obj[attrs[i]]).toFixed(2));\n        }\n        var line = \"<span style='float:left;clear:left;font_size=0.5pt'><b>\" + cb_obj.event_name + \"</b>(\" + args.join(\", \") + \")</span>\\n\";\n        var text = div.text.concat(line);\n        var lines = text.split(\"\\n\")\n        if ( lines.length > 35 ) { lines.shift(); }\n        div.text = lines.join(\"\\n\");\n    "},"id":"a3c780ec-f352-4f99-bdc3-9dc1a35fd98f","type":"CustomJS"},{"attributes":{"children":[{"id":"a5bbefec-09fb-4612-b584-517fb9f138ca","subtype":"Figure","type":"Plot"},{"id":"995bf61c-6790-4eac-9702-9ff343a7e3ec","type":"WidgetBox"}]},"id":"358f78bd-e0c8-4730-8268-87b576a40b25","type":"Row"},{"attributes":{"args":{"div":{"id":"491e9f36-dcba-4cf2-a022-385b7f408a8a","type":"Div"}},"code":"\n        var attrs = ['x', 'y', 'sx', 'sy', 'scale']; var args = [];\n        for (var i=0; i<attrs.length; i++ ) {\n            args.push(attrs[i] + '=' + Number(cb_obj[attrs[i]]).toFixed(2));\n        }\n        var line = \"<span style='float:left;clear:left;font_size=0.5pt'><b>\" + cb_obj.event_name + \"</b>(\" + args.join(\", \") + \")</span>\\n\";\n        var text = div.text.concat(line);\n        var lines = text.split(\"\\n\")\n        if ( lines.length > 35 ) { lines.shift(); }\n        div.text = lines.join(\"\\n\");\n    "},"id":"46fd87b5-78b7-4501-9e6e-eb75d8263377","type":"CustomJS"},{"attributes":{"children":[{"id":"491e9f36-dcba-4cf2-a022-385b7f408a8a","type":"Div"}],"width":1000},"id":"995bf61c-6790-4eac-9702-9ff343a7e3ec","type":"WidgetBox"},{"attributes":{"children":[{"id":"9fbde245-8579-4489-aa40-e7a6c74e3201","type":"Button"}]},"id":"464c23c2-40a8-4187-998c-534b6c9a5d38","type":"WidgetBox"},{"attributes":{"children":[{"id":"464c23c2-40a8-4187-998c-534b6c9a5d38","type":"WidgetBox"},{"id":"358f78bd-e0c8-4730-8268-87b576a40b25","type":"Row"}]},"id":"a528c584-b28d-439b-8b8a-2421a72b37dc","type":"Column"},{"attributes":{"args":{"div":{"id":"491e9f36-dcba-4cf2-a022-385b7f408a8a","type":"Div"}},"code":"\n        var attrs = ['x', 'y', 'sx', 'sy']; var args = [];\n        for (var i=0; i<attrs.length; i++ ) {\n            args.push(attrs[i] + '=' + Number(cb_obj[attrs[i]]).toFixed(2));\n        }\n        var line = \"<span style='float:left;clear:left;font_size=0.5pt'><b>\" + cb_obj.event_name + \"</b>(\" + args.join(\", \") + \")</span>\\n\";\n        var text = div.text.concat(line);\n        var lines = text.split(\"\\n\")\n        if ( lines.length > 35 ) { lines.shift(); }\n        div.text = lines.join(\"\\n\");\n    "},"id":"5e71eb8e-e11a-406f-843e-b2c6fd4e4f40","type":"CustomJS"},{"attributes":{"args":{"div":{"id":"491e9f36-dcba-4cf2-a022-385b7f408a8a","type":"Div"}},"code":"\n        var attrs = []; var args = [];\n        for (var i=0; i<attrs.length; i++ ) {\n            args.push(attrs[i] + '=' + Number(cb_obj[attrs[i]]).toFixed(2));\n        }\n        var line = \"<span style='float:l ...
# bokeh.models.widgets.buttons.Button
