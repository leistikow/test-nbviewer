# %%
import numpy as np

from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0af5fd47-5f3e-43c3-b959-ed4bc4d182f1">Loading BokehJS ...</span>
#     </div>

# %%
import numpy as np
from bokeh.io import show, output_file
from bokeh.plotting import figure
from bokeh import events
from bokeh.models import CustomJS, Div, Button
from bokeh.layouts import column, row

def display_event(div, attributes=[], style = 'float:left;clear:left;font_size=0.5pt'):
    "Build a suitable CustomJS to display the current event in the div model."
    return CustomJS(args=dict(div=div), code="""
        var attrs = %s; var args = [];
        for (var i=0; i<attrs.length; i++ ) {
            args.push(attrs[i] + '=' + Number(cb_obj[attrs[i]]).toFixed(2));
        }
        var line = "<span style=%r><b>" + cb_obj.event_name + "</b>(" + args.join(", ") + ")</span>\\n";
        var text = div.text.concat(line);
        var lines = text.split("\\n")
        if ( lines.length > 35 ) { lines.shift(); }
        div.text = lines.join("\\n");
    """ % (attributes, style))

x = np.random.random(size=4000) * 100
y = np.random.random(size=4000) * 100
radii = np.random.random(size=4000) * 1.5
colors = ["#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(50+2*x, 30+2*y)]

p = figure(tools="pan,wheel_zoom,zoom_in,zoom_out,reset")
p.scatter(x, y, radius=np.random.random(size=4000) * 1.5,
          fill_color=colors, fill_alpha=0.6, line_color=None)

div = Div(width=1000)
button = Button(label="Button", button_type="success")
layout = column(button, row(p, div))

## Events with no attributes
button.js_on_event(events.ButtonClick, display_event(div)) # Button click
p.js_on_event(events.LODStart, display_event(div))         # Start of LOD display
p.js_on_event(events.LODEnd, display_event(div))           # End of LOD display

## Events with attributes
point_attributes = ['x','y','sx','sy']                     # Point events
wheel_attributes = point_attributes+['delta']              # Mouse wheel event
pan_attributes = point_attributes + ['delta_x', 'delta_y'] # Pan event
pinch_attributes = point_attributes + ['scale']            # Pinch event

point_events =  [events.Tap, events.DoubleTap, events.Press,
                 events.MouseMove, events.MouseEnter, events.MouseLeave,
                 events.PanStart, events.PanEnd, events.PinchStart, events.PinchEnd]

for event in point_events:
    p.js_on_event(event,display_event(div, attributes=point_attributes))

p.js_on_event(events.MouseWheel, display_event(div,attributes=wheel_attributes))
p.js_on_event(events.Pan,        display_event(div, attributes=pan_attributes))
p.js_on_event(events.Pinch,      display_event(div, attributes=pinch_attributes))

output_file("js_events.html", title="JS Events Example")
show(layout)
Button
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="be14a0f9-4640-4e7b-9e89-6cca179ddeef"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("be14a0f9-4640-4e7b-9e89-6cca179ddeef");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("be14a0f9-4640-4e7b-9e89-6cca179ddeef");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'be14a0f9-4640-4e7b-9e89-6cca179ddeef' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b2f2a39d-3b3e-4ae4-9e06-cba7df9f70d7":{"roots":{"references":[{"attributes":{"args":{"div":{"id":"572cb381-62a1-4807-a10c-641a3967376d","type":"Div"}},"code":"\n        var attrs = ['x', 'y', 'sx', 'sy', 'scale']; var args = [];\n        for (var i=0; i<attrs.length; i++ ) {\n            args.push(attrs[i] + '=' + Number(cb_obj[attrs[i]]).toFixed(2));\n        }\n        var line = \"<span style='float:left;clear:left;font_size=0.5pt'><b>\" + cb_obj.event_name + \"</b>(\" + args.join(\", \") + \")</span>\\n\";\n        var text = div.text.concat(line);\n        var lines = text.split(\"\\n\")\n        if ( lines.length > 35 ) { lines.shift(); }\n        div.text = lines.join(\"\\n\");\n    "},"id":"b4cbc645-6b11-4cda-940a-085418be483a","type":"CustomJS"},{"attributes":{},"id":"abe3de29-e4ab-4d35-909d-61495fee27f9","type":"ToolEvents"},{"attributes":{"args":{"div":{"id":"572cb381-62a1-4807-a10c-641a3967376d","type":"Div"}},"code":"\n        var attrs = ['x', 'y', 'sx', 'sy']; var args = [];\n        for (var i=0; i<attrs.length; i++ ) {\n            args.push(attrs[i] + '=' + Number(cb_obj[attrs[i]]).toFixed(2));\n        }\n        var line = \"<span style='float:left;clear:left;font_size=0.5pt'><b>\" + cb_obj.event_name + \"</b>(\" + args.join(\", \") + \")</span>\\n\";\n        var text = div.text.concat(line);\n        var lines = text.split(\"\\n\")\n        if ( lines.length > 35 ) { lines.shift(); }\n        div.text = lines.join(\"\\n\");\n    "},"id":"c024a8c0-5fd2-488e-a286-2ecf729e32d9","type":"CustomJS"},{"attributes":{},"id":"df5f5a27-905b-4f5a-82e5-37f49c976bfc","type":"LinearScale"},{"attributes":{"args":{"div":{"id":"572cb381-62a1-4807-a10c-641a3967376d","type":"Div"}},"code":"\n        var attrs = ['x', 'y', 'sx', 'sy']; var args = [];\n        for (var i=0; i<attrs.length; i++ ) {\n            args.push(attrs[i] + '=' + Number(cb_obj[attrs[i]]).toFixed(2));\n        }\n        var line = \"<span style='float:left;clear:left;font_size=0.5pt'><b>\" + cb_obj.event_name + \"</b>(\" + args.join(\", \") + \")</span>\\n\";\n        var text = div.text.concat(line);\n        var lines = text.split(\"\\n\")\n        if ( lines.length > 35 ) { lines.shift(); }\n        div.text = lines.join(\"\\n\");\n    "},"id":"31b203a1-82ab-41e5-bede-daec04dc0c4c","type":"CustomJS"},{"attributes":{"below":[{"id":"f675ad5c-44f4-4ea5-9270-d2f7287f82f7","type":"LinearAxis"}],"js_event_callbacks":{"doubletap":[{"id":"c024a8c0-5fd2-488e-a286-2ecf729e32d9","type":"CustomJS"}],"lodend":[{"id":"ce32f643-769e-4559-a64f-50c65dbedcf4","type":"CustomJS"}],"lodstart":[{"id":"f9d30771-548b-4a8d-9cc9-b2ffa7f7e5e8","type":"CustomJS"}],"mouseenter":[{"id":"364b89f3-61f5-4a73-906e-c06ee40daacd","type":"CustomJS"}],"mouseleave":[{"id":"4618894a-12e3-485f-8e3c-1f85fe201ec9","type":"CustomJS"}],"mousemove":[{"id":"8b966ea9-bc81-4efa-b43b-f1bb1d1ff492","type":"CustomJS"}],"pan":[{"id":"e7c5e79f-6e6a-4bb0-88b4-c06522940ae1","type":"CustomJS"}],"panend":[{"id":"7f70ac1a-a3d2-4427-93a4-99fff507c99b","type":"CustomJS"}],"panstart":[{"id":"c9fde2ba-4c72-40e3-8450-116c0f40a909","type":"CustomJS"}],"pinch":[{"id":"b4cbc645-6b11-4cda-940a-085418be483a","type":"CustomJS"}],"pinchend":[{"id":"b4e37df8-3647-4ce7-ac73-00452a367725","type":"CustomJS"}],"pinchstart":[{"id":"423fa843-e1de-4fa9-b5b8-96367c23e14f","type":"CustomJS"}],"press":[{"id":"31b203a1-82ab-41e5-bede-daec04dc0c4c","type":"CustomJS"}],"tap":[{"id":"44ff4f42-68ae-4598-8625-ea3f5cb19469","type":"CustomJS"}],"wheel":[{"id":"5b5743cf-9cb7-4f19-91bf-93684030e9ef","type":"CustomJS"}]},"left":[{"id":"638f7370-6002-4a48-8ba2-cabb6ea74982","type":"LinearAxis"}],"renderers":[{"id":"f675ad5c-44f4-4ea5-9270-d2f7287f82f7","type":"LinearAxis"},{"id":"4476fa44-4a5a-460d-981c-80cbd9f5a1f4","type":"Grid"},{"id":"638f7370-6002-4a48-8ba2-cabb6ea74982","type":"LinearAxis"},{"id":"04e7deb8-0081-4e22-bf20-8cf46fee0f5d","type":"Grid"},{"id":"df1e744d-4b91-454a-bf2b-5d99bc945133","type":"Glyph ...
# bokeh.models.widgets.buttons.Button

# %%
from bokeh.layouts import column
from bokeh.models import CustomJS, ColumnDataSource, Slider
from bokeh.plotting import Figure, output_file, show

output_file("js_on_change.html")

x = [x*0.005 for x in range(0, 200)]
y = x

source = ColumnDataSource(data=dict(x=x, y=y))

plot = Figure(plot_width=400, plot_height=400)
plot.line('x', 'y', source=source, line_width=3, line_alpha=0.6)

callback = CustomJS(args=dict(source=source), code="""
    var data = source.data;
    var f = cb_obj.value
    x = data['x']
    y = data['y']
    for (i = 0; i < x.length; i++) {
        y[i] = Math.pow(x[i], f)
    }
    source.change.emit();
""")

slider = Slider(start=0.1, end=4, value=1, step=.1, title="power")
slider.js_on_change('value', callback)

layout = column(slider, plot)

show(layout)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="709f1e35-6fac-4d48-939a-7a8501a12507"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("709f1e35-6fac-4d48-939a-7a8501a12507");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("709f1e35-6fac-4d48-939a-7a8501a12507");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '709f1e35-6fac-4d48-939a-7a8501a12507' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f81bd190-74a1-4c9e-98f8-b7838589e14b":{"roots":{"references":[{"attributes":{"plot":null,"text":""},"id":"17db8453-aaee-43d8-86b4-54f2482d5681","type":"Title"},{"attributes":{"plot":{"id":"9adfc190-b950-46fe-896e-0e2e2d5cbe16","subtype":"Figure","type":"Plot"}},"id":"46452bad-63b8-404a-b9d3-b0fba2115334","type":"HelpTool"},{"attributes":{},"id":"5a2656ee-e7fe-4894-8e65-dcdda409cbe8","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"4aa3f555-6215-431d-ad8a-01c0a4b4dbbe","type":"BoxAnnotation"},"plot":{"id":"9adfc190-b950-46fe-896e-0e2e2d5cbe16","subtype":"Figure","type":"Plot"}},"id":"73debf80-657c-4991-b821-c4d142c86d7e","type":"BoxZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"f1867af4-bb4c-463a-b71f-0e84737d7664","type":"Line"},{"attributes":{"plot":{"id":"9adfc190-b950-46fe-896e-0e2e2d5cbe16","subtype":"Figure","type":"Plot"}},"id":"b386ff69-1a7a-4113-bfc0-f7c81764bb5e","type":"ResetTool"},{"attributes":{"children":[{"id":"aca1c225-db49-4ece-b6eb-da203d3737a4","type":"WidgetBox"},{"id":"9adfc190-b950-46fe-896e-0e2e2d5cbe16","subtype":"Figure","type":"Plot"}]},"id":"d09c0416-5648-43c6-8083-e48fd2acdf20","type":"Column"},{"attributes":{},"id":"d722bf46-0853-4e20-b1c4-fc2bae6f7b5c","type":"BasicTicker"},{"attributes":{},"id":"9c41c40b-b1c3-4efe-ba8d-45967a76666f","type":"BasicTicker"},{"attributes":{},"id":"341f738f-800b-484c-ab95-e500b8d78932","type":"BasicTickFormatter"},{"attributes":{},"id":"412362ac-0ed3-4f13-84d4-0a60e3d022ff","type":"LinearScale"},{"attributes":{"plot":{"id":"9adfc190-b950-46fe-896e-0e2e2d5cbe16","subtype":"Figure","type":"Plot"}},"id":"9bda5f1c-be15-4a6e-8c5a-2514ff437ba5","type":"PanTool"},{"attributes":{"formatter":{"id":"5a2656ee-e7fe-4894-8e65-dcdda409cbe8","type":"BasicTickFormatter"},"plot":{"id":"9adfc190-b950-46fe-896e-0e2e2d5cbe16","subtype":"Figure","type":"Plot"},"ticker":{"id":"9c41c40b-b1c3-4efe-ba8d-45967a76666f","type":"BasicTicker"}},"id":"25a435f8-7540-4057-a133-6cd03b5de7b5","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"9adfc190-b950-46fe-896e-0e2e2d5cbe16","subtype":"Figure","type":"Plot"},"ticker":{"id":"d722bf46-0853-4e20-b1c4-fc2bae6f7b5c","type":"BasicTicker"}},"id":"4e217e63-ab44-4da7-89cc-4bcccbb56c90","type":"Grid"},{"attributes":{"line_alpha":{"value":0.6},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"e27e9a05-0dc6-45fb-8aba-1984e8377ae3","type":"Line"},{"attributes":{"children":[{"id":"ff7e4903-9ffb-4b29-9959-c6b4c43581ba","type":"Slider"}]},"id":"aca1c225-db49-4ece-b6eb-da203d3737a4","type":"WidgetBox"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"9bda5f1c-be15-4a6e-8c5a-2514ff437ba5","type":"PanTool"},{"id":"c630b7fd-f0d6-45b3-bb17-b91c5354087e","type":"WheelZoomTool"},{"id":"73debf80-657c-4991-b821-c4d142c86d7e","type":"BoxZoomTool"},{"id":"1bfac2e9-6a4c-4f4b-ba7d-ed5fb91fe323","type":"SaveTool"},{"id":"b386ff69-1a7a-4113-bfc0-f7c81764bb5e","type":"ResetTool"},{"id":"46452bad-63b8-404a-b9d3-b0fba2115334","type":"HelpTool"}]},"id":"639b3f34-3b8f-4643-8704-66767092ed6b","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.0,0.005,0.01,0.015,0.02,0.025,0.03,0.035,0.04,0.045,0.05,0.055,0.06,0.065,0.07,0.075,0.08,0.085,0.09,0.095,0.1,0.105,0.11,0.115,0.12,0.125,0.13,0.135,0.14,0.145,0.15,0.155,0.16,0.165,0.17,0.17500000000000002,0.18,0.185,0.19,0.195,0.2,0.20500000000000002,0.21,0.215,0.22,0.225,0.23,0.23500000000000001,0.24,0.245,0.25,0.255,0.26,0.265,0.27,0.275,0.28,0.28500000000000003,0.29,0.295,0.3,0.305,0.31,0.315,0.32,0.325,0.33,0.335,0.34,0.34500000000000003,0.35000000000000003,0.355,0.36,0.365,0.37,0.375,0.38,0.385,0.39,0.395,0.4,0.405,0.41000000000000003,0.41500000000000004,0.42,0.425,0.43,0.435,0.44,0.445,0.45,0.455,0.46,0.465,0.4700000000000 ...
