# %% [markdown]
# Basic Interactor Demo
# ---------------------
#
# This demo shows off an interactive visualization using [Bokeh](https://bokeh.pydata.org) for plotting, and Ipython interactors for widgets. The demo runs entirely inside the Ipython notebook, with no Bokeh server required.
#
# The dropdown offers a choice of trig functions to plot, and the sliders control the frequency, amplitude, and phase.
#
# To run, click on, `Cell->Run All` in the top menu, then scroll to the bottom and move the sliders.

# %%
from ipywidgets import interact
import numpy as np

from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4405c287-bd6c-4524-9e47-0c66dbd00f46">Loading BokehJS ...</span>
#     </div>

# %%
x = np.linspace(0, 2*np.pi, 2000)
y = np.sin(x)

# %%
p = figure(title="simple line example", plot_height=300, plot_width=600, y_range=(-5,5))
r = p.line(x, y, color="#2222aa", line_width=3)

# %%
def update(f, w=1, A=1, phi=0):
    if   f == "sin": func = np.sin
    elif f == "cos": func = np.cos
    elif f == "tan": func = np.tan
    r.data_source.data['y'] = A * func(w * x + phi)
    push_notebook()

# %%
show(p, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="cb844049-5dec-49bb-a2e2-aeb3d6d00c7f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("cb844049-5dec-49bb-a2e2-aeb3d6d00c7f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("83c9107e-3874-405f-977b-2cba81f40c35", function () {});
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cb844049-5dec-49bb-a2e2-aeb3d6d00c7f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cb844049-5dec-49bb-a2e2-aeb3d6d00c7f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cfcfe77a-6ae2-4e53-b1a9-3431dfea0930":{"roots":{"references":[{"attributes":{"plot":{"id":"a3e8f107-07d3-4451-ad59-bbab877a4176","subtype":"Figure","type":"Plot"}},"id":"c59840b9-d66d-4b79-9f2a-e47d440df89b","type":"HelpTool"},{"attributes":{},"id":"d0be0769-9913-4f22-be90-178689e6d233","type":"LinearScale"},{"attributes":{"formatter":{"id":"e6feff50-b326-43ac-84a7-cb72c38fc48e","type":"BasicTickFormatter"},"plot":{"id":"a3e8f107-07d3-4451-ad59-bbab877a4176","subtype":"Figure","type":"Plot"},"ticker":{"id":"665a474f-2475-4124-8b92-760a0900d8b6","type":"BasicTicker"}},"id":"4dfb02b5-7bf7-47ee-8242-b2d6ed3a01a0","type":"LinearAxis"},{"attributes":{},"id":"665a474f-2475-4124-8b92-760a0900d8b6","type":"BasicTicker"},{"attributes":{"plot":{"id":"a3e8f107-07d3-4451-ad59-bbab877a4176","subtype":"Figure","type":"Plot"},"ticker":{"id":"665a474f-2475-4124-8b92-760a0900d8b6","type":"BasicTicker"}},"id":"51db26d7-13cf-44d0-926f-9cb68162b8d1","type":"Grid"},{"attributes":{"formatter":{"id":"0317f2e2-fd4d-4315-bd72-db905a3504dc","type":"BasicTickFormatter"},"plot":{"id":"a3e8f107-07d3-4451-ad59-bbab877a4176","subtype":"Figure","type":"Plot"},"ticker":{"id":"ae84de13-c221-4452-995f-a2d099365326","type":"BasicTicker"}},"id":"60ff4d2d-b59c-4a86-b71a-687eca60a5fb","type":"LinearAxis"},{"attributes":{"data_source":{"id":"836a7415-89bf-4322-8999-b36cf04e4871","type":"ColumnDataSource"},"glyph":{"id":"23c2ba3d-f386-4030-b095-b1fb939b1472","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"5be6bb89-b104-4656-ab94-a9fe062c8863","type":"Line"},"selection_glyph":null},"id":"0abae7d6-f29f-4fec-8953-bcf06449b96e","type":"GlyphRenderer"},{"attributes":{},"id":"ae84de13-c221-4452-995f-a2d099365326","type":"BasicTicker"},{"attributes":{},"id":"e6feff50-b326-43ac-84a7-cb72c38fc48e","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"a3e8f107-07d3-4451-ad59-bbab877a4176","subtype":"Figure","type":"Plot"},"ticker":{"id":"ae84de13-c221-4452-995f-a2d099365326","type":"BasicTicker"}},"id":"3ea80f52-21cf-49de-8026-c72db89d8b7b","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"be51d403-c53b-450c-a081-b65f2abaebb8","type":"BoxAnnotation"},{"attributes":{},"id":"0317f2e2-fd4d-4315-bd72-db905a3504dc","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[2000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[2000]}}},"id":"836a7415-89bf-4322-8999-b36cf04e4871","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"4dfb02b5-7bf7-47ee-8242-b2d6ed3a01a0","type":"LinearAxis"}],"left":[{"id":"60ff4d2d-b59c-4a86-b71a-687eca60a5fb","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"4dfb02b5-7bf7-47ee-8242-b2d6ed3a01a0","type":"LinearAxis"},{"id":"51db26d7-13cf-44d0-926f-9cb68162b8d1","type":"Grid"},{"id":"60ff4d2d-b59c-4a86-b71a-687eca60a5fb","type":"LinearAxis"},{"id":"3ea80f52-21cf-49de-8026-c72db89d8b7b","type":"Grid"},{"id":"be51d403-c53b-450c-a081-b65f2abaebb8","type":"BoxAnnotation"},{"id":"0abae7d6-f29f-4fec-8953-bcf06449b96e","type":"GlyphRenderer"}],"title":{"id":"6e366149-17da-4f18-b5db-86eddee33d2a","type":"Title"},"tool_events":{"id":"77e4ea50-ae60-4d55-be5b-bb8afb9c52f2","type":"ToolEvents"},"toolbar":{"id":"3015242d-7e2b-45ff-bd05-0ab56c3d933b","type":"Toolbar"},"x_range":{"id":"1893c795-dc44-457d-b5d2-86662e0bd041","type":"DataRange1d"},"x_scale":{"id":"41a0d06f-0dff-4f98-8f39-08527d99e0b3","type":"LinearScale"},"y_range":{"id":"5407932e-5c46-42c2-99b2-ac327965f2df","type":"Range1d"},"y_scale":{"id":"d0be0769-9913-4f22-be90-178689e6d233","type":"LinearScale"}},"id":"a3e8f107-07d3-4451-ad59-b ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[5]</strong>&gt;</code></p>

# %%
interact(update, f=["sin", "cos", "tan"], w=(0,100), A=(1,5), phi=(0, 20, 0.1))
# Out:
# /opt/conda/lib/python3.6/site-packages/bokeh/models/sources.py:91: BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 2000), ('y', 4000)
#   "Current lengths: %s" % ", ".join(sorted(str((k, len(v))) for k, v in data.items())), BokehUserWarning))

# %%
from bokeh.io import output_file, show
from bokeh.layouts import widgetbox
from bokeh.models.widgets import Button

output_file("button.html")

button = Button(label="Foo", button_type="success")

show(widgetbox(button))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e6bd1a12-f184-42a8-ab1b-0a1f21c9cb49"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e6bd1a12-f184-42a8-ab1b-0a1f21c9cb49");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e6bd1a12-f184-42a8-ab1b-0a1f21c9cb49");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e6bd1a12-f184-42a8-ab1b-0a1f21c9cb49' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b8c73cef-14fa-4e81-9627-1d960f5353a1":{"roots":{"references":[{"attributes":{"children":[{"id":"04e19c5e-3571-4aa1-be35-23c4f2df1d79","type":"Button"}]},"id":"bc50e457-8cd2-4bc4-9cbf-9f44a20ded3a","type":"WidgetBox"},{"attributes":{"button_type":"success","callback":null,"icon":null,"label":"Foo"},"id":"04e19c5e-3571-4aa1-be35-23c4f2df1d79","type":"Button"}],"root_ids":["bc50e457-8cd2-4bc4-9cbf-9f44a20ded3a"]},"title":"Bokeh Application","version":"0.12.6"}};
#             var render_items = [{"docid":"b8c73cef-14fa-4e81-9627-1d960f5353a1","elementid":"e6bd1a12-f184-42a8-ab1b-0a1f21c9cb49","modelid":"bc50e457-8cd2-4bc4-9cbf-9f44a20ded3a"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#           };
#           if (document.readyState != "loading") fn();
#           else document.addEventListener("DOMContentLoaded", fn);
#         })();
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#
#       if ((window.Bokeh !== undefined) || (force === true)) {
#         for (var i = 0; i < inline_js.length; i++) {
#           inline_js[i](window.Bokeh);
#         }if (force === true) {
#           display_loaded();
#         }} else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(run_inline_js, 100);
#       } else if (!window._bokeh_failed_load) {
#         console.log("Bokeh: BokehJS failed to load within specified timeout.");
#         window._bokeh_failed_load = true;
#       } else if (force !== true) {
#         var cell = $(document.getElementById("e6bd1a12-f184-42a8-ab1b-0a1f21c9cb49")).parents('.cell').data().cell;
#         cell.output_area.append_execute_result(NB_LOAD_WARNING)
#       }
#
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(this));
# </script>

# %%
import numpy as np
from bokeh.io import show, output_file
from bokeh.plotting import figure
from bokeh import events
from bokeh.models import CustomJS, Div, Button
from bokeh.layouts import column, row

def display_event(div, attributes=[], style = 'float:left;clear:left;font_size=0.5pt'):
    "Build a suitable CustomJS to display the current event in the div model."
    return CustomJS(args=dict(div=div), code="""
        var attrs = %s; var args = [];
        for (var i=0; i<attrs.length; i++ ) {
            args.push(attrs[i] + '=' + Number(cb_obj[attrs[i]]).toFixed(2));
        }
        var line = "<span style=%r><b>" + cb_obj.event_name + "</b>(" + args.join(", ") + ")</span>\\n";
        var text = div.text.concat(line);
        var lines = text.split("\\n")
        if ( lines.length > 35 ) { lines.shift(); }
        div.text = lines.join("\\n");
    """ % (attributes, style))

x = np.random.random(size=4000) * 100
y = np.random.random(size=4000) * 100
radii = np.random.random(size=4000) * 1.5
colors = ["#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(50+2*x, 30+2*y)]

p = figure(tools="pan,wheel_zoom,zoom_in,zoom_out,reset")
p.scatter(x, y, radius=np.random.random(size=4000) * 1.5,
          fill_color=colors, fill_alpha=0.6, line_color=None)

div = Div(width=1000)
button = Button(label="Button", button_type="success")
layout = column(button, row(p, div))

## Events with no attributes
button.js_on_event(events.ButtonClick, display_event(div)) # Button click
p.js_on_event(events.LODStart, display_event(div))         # Start of LOD display
p.js_on_event(events.LODEnd, display_event(div))           # End of LOD display

## Events with attributes
point_attributes = ['x','y','sx','sy']                     # Point events
wheel_attributes = point_attributes+['delta']              # Mouse wheel event
pan_attributes = point_attributes + ['delta_x', 'delta_y'] # Pan event
pinch_attributes = point_attributes + ['scale']            # Pinch event

point_events =  [events.Tap, events.DoubleTap, events.Press,
                 events.MouseMove, events.MouseEnter, events.MouseLeave,
                 events.PanStart, events.PanEnd, events.PinchStart, events.PinchEnd]

for event in point_events:
    p.js_on_event(event,display_event(div, attributes=point_attributes))

p.js_on_event(events.MouseWheel, display_event(div,attributes=wheel_attributes))
p.js_on_event(events.Pan,        display_event(div, attributes=pan_attributes))
p.js_on_event(events.Pinch,      display_event(div, attributes=pinch_attributes))

output_file("js_events.html", title="JS Events Example")
show(layout)
Button
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4bb1d206-996d-4a43-971a-b86ca7847934"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4bb1d206-996d-4a43-971a-b86ca7847934");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4bb1d206-996d-4a43-971a-b86ca7847934");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4bb1d206-996d-4a43-971a-b86ca7847934' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"399f949a-c1a5-49f2-886a-29d990edbde7":{"roots":{"references":[{"attributes":{},"id":"3cea8e4b-1baa-4444-b7d0-ec64b1ee4146","type":"BasicTickFormatter"},{"attributes":{},"id":"6ffdb24e-04fb-4e1a-a88b-bd364b6d6fc3","type":"ToolEvents"},{"attributes":{"args":{"div":{"id":"baaff40f-d4b4-4749-99de-a96482c1d76e","type":"Div"}},"code":"\n        var attrs = []; var args = [];\n        for (var i=0; i<attrs.length; i++ ) {\n            args.push(attrs[i] + '=' + Number(cb_obj[attrs[i]]).toFixed(2));\n        }\n        var line = \"<span style='float:left;clear:left;font_size=0.5pt'><b>\" + cb_obj.event_name + \"</b>(\" + args.join(\", \") + \")</span>\\n\";\n        var text = div.text.concat(line);\n        var lines = text.split(\"\\n\")\n        if ( lines.length > 35 ) { lines.shift(); }\n        div.text = lines.join(\"\\n\");\n    "},"id":"1c4acf8b-981a-4747-a39f-367216a74816","type":"CustomJS"},{"attributes":{"args":{"div":{"id":"baaff40f-d4b4-4749-99de-a96482c1d76e","type":"Div"}},"code":"\n        var attrs = []; var args = [];\n        for (var i=0; i<attrs.length; i++ ) {\n            args.push(attrs[i] + '=' + Number(cb_obj[attrs[i]]).toFixed(2));\n        }\n        var line = \"<span style='float:left;clear:left;font_size=0.5pt'><b>\" + cb_obj.event_name + \"</b>(\" + args.join(\", \") + \")</span>\\n\";\n        var text = div.text.concat(line);\n        var lines = text.split(\"\\n\")\n        if ( lines.length > 35 ) { lines.shift(); }\n        div.text = lines.join(\"\\n\");\n    "},"id":"05d03046-c560-422a-91f9-33ec29171cb8","type":"CustomJS"},{"attributes":{"args":{"div":{"id":"baaff40f-d4b4-4749-99de-a96482c1d76e","type":"Div"}},"code":"\n        var attrs = []; var args = [];\n        for (var i=0; i<attrs.length; i++ ) {\n            args.push(attrs[i] + '=' + Number(cb_obj[attrs[i]]).toFixed(2));\n        }\n        var line = \"<span style='float:left;clear:left;font_size=0.5pt'><b>\" + cb_obj.event_name + \"</b>(\" + args.join(\", \") + \")</span>\\n\";\n        var text = div.text.concat(line);\n        var lines = text.split(\"\\n\")\n        if ( lines.length > 35 ) { lines.shift(); }\n        div.text = lines.join(\"\\n\");\n    "},"id":"bd1df81d-dfe3-41f7-9c7f-8cb73c28e208","type":"CustomJS"},{"attributes":{"children":[{"id":"f4422b62-6803-418e-b5bd-b60e6719ff2e","subtype":"Figure","type":"Plot"},{"id":"a321149d-f323-45f6-b5d1-6a9955821e11","type":"WidgetBox"}]},"id":"fb689111-c4aa-4a4f-a970-759337295c2d","type":"Row"},{"attributes":{"children":[{"id":"baaff40f-d4b4-4749-99de-a96482c1d76e","type":"Div"}],"width":1000},"id":"a321149d-f323-45f6-b5d1-6a9955821e11","type":"WidgetBox"},{"attributes":{"children":[{"id":"c996ffe2-0a78-41d7-85ae-5f3e95630228","type":"Button"}]},"id":"56a5b79b-cac4-4c1d-b347-8c0d3e0b63ac","type":"WidgetBox"},{"attributes":{"width":1000},"id":"baaff40f-d4b4-4749-99de-a96482c1d76e","type":"Div"},{"attributes":{"below":[{"id":"22cf0a40-41f5-4489-817a-2051c5472cb6","type":"LinearAxis"}],"js_event_callbacks":{"doubletap":[{"id":"a4f904db-d4e2-4def-9714-66da8e141fb0","type":"CustomJS"}],"lodend":[{"id":"bd1df81d-dfe3-41f7-9c7f-8cb73c28e208","type":"CustomJS"}],"lodstart":[{"id":"05d03046-c560-422a-91f9-33ec29171cb8","type":"CustomJS"}],"mouseenter":[{"id":"099bff5e-f3d3-4cbe-8fc6-545b691513de","type":"CustomJS"}],"mouseleave":[{"id":"85010825-624b-4528-91d8-b36b360e80fd","type":"CustomJS"}],"mousemove":[{"id":"6cfe0ecb-c4e7-4431-8660-b2c263afb9a8","type":"CustomJS"}],"pan":[{"id":"89b07b5d-b59f-41e4-8bdd-3879b9cec4cf","type":"CustomJS"}],"panend":[{"id":"c54124bb-064b-4853-9bb4-1052c5b21108","type":"CustomJS"}],"panstart":[{"id":"7f1491c7-47c5-4800-8544-079f4d3401d1","type":"CustomJS"}],"pinch":[{"id":"d4af45c8-167f-4eb4-bc37-68d557b516bc","type":"CustomJS"}],"pinchend":[{"id":"119348b4-534e-486c-aa22-bd4d686bafa9","type":"CustomJS"}],"pinchstart":[{"id":"8468cb93-8e37-4d46-8630-063bbe3b4cd4","type":"CustomJS"}],"press":[{"id":"fc65387e-4ab7-45d5-9b11-a98 ...
# bokeh.models.widgets.buttons.Button

# %%
from bokeh.layouts import column
from bokeh.models import CustomJS, ColumnDataSource, Slider
from bokeh.plotting import Figure, output_file, show

output_file("js_on_change.html")

x = [x*0.005 for x in range(0, 200)]
y = x

source = ColumnDataSource(data=dict(x=x, y=y))

plot = Figure(plot_width=400, plot_height=400)
plot.line('x', 'y', source=source, line_width=3, line_alpha=0.6)

callback = CustomJS(args=dict(source=source), code="""
    var data = source.data;
    var f = cb_obj.value
    x = data['x']
    y = data['y']
    for (i = 0; i < x.length; i++) {
        y[i] = Math.pow(x[i], f)
    }
    source.change.emit();
""")

slider = Slider(start=0.1, end=4, value=1, step=.1, title="power")
slider.js_on_change('value', callback)

layout = column(slider, plot)

show(layout)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="186fdbcf-ab4b-4af2-a78d-ca3e7d25bc4d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("186fdbcf-ab4b-4af2-a78d-ca3e7d25bc4d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("186fdbcf-ab4b-4af2-a78d-ca3e7d25bc4d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '186fdbcf-ab4b-4af2-a78d-ca3e7d25bc4d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f51d6191-06c9-4378-894c-a26158fc0df3":{"roots":{"references":[{"attributes":{"formatter":{"id":"5d1158ab-3fbf-41eb-b701-eaa18759df7a","type":"BasicTickFormatter"},"plot":{"id":"001a0324-58df-4b60-ba3a-4a7815286074","subtype":"Figure","type":"Plot"},"ticker":{"id":"de3ada90-6131-4535-bdb2-15721ad9d2a0","type":"BasicTicker"}},"id":"c8275c26-fb0c-47a3-b828-132f185743a1","type":"LinearAxis"},{"attributes":{"overlay":{"id":"6ded386c-fca1-4f3c-aaa7-129b7299b6fa","type":"BoxAnnotation"},"plot":{"id":"001a0324-58df-4b60-ba3a-4a7815286074","subtype":"Figure","type":"Plot"}},"id":"217663f2-4af1-4ab2-b3df-dc5b85667eba","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"3ba8ab6b-3dca-4d98-a194-25306d6787e8","type":"DataRange1d"},{"attributes":{"plot":{"id":"001a0324-58df-4b60-ba3a-4a7815286074","subtype":"Figure","type":"Plot"}},"id":"53b867f5-9b78-4ce5-9c14-79713a4856eb","type":"PanTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"53b867f5-9b78-4ce5-9c14-79713a4856eb","type":"PanTool"},{"id":"35a176c5-f1d1-42f0-8bc3-197c6587dd6c","type":"WheelZoomTool"},{"id":"217663f2-4af1-4ab2-b3df-dc5b85667eba","type":"BoxZoomTool"},{"id":"5637a336-0fb3-4a88-a721-08f6e4428dcf","type":"SaveTool"},{"id":"21bf42ce-8828-4c4a-a0d3-9dbf4bb5b655","type":"ResetTool"},{"id":"58e29aa5-11bd-430e-b499-6a5980d8dfd0","type":"HelpTool"}]},"id":"7c8cba01-90be-482b-a83e-f4b1643fbdf3","type":"Toolbar"},{"attributes":{},"id":"5d1158ab-3fbf-41eb-b701-eaa18759df7a","type":"BasicTickFormatter"},{"attributes":{},"id":"e29f745b-afb9-4215-b685-36ef5583f11c","type":"LinearScale"},{"attributes":{"plot":{"id":"001a0324-58df-4b60-ba3a-4a7815286074","subtype":"Figure","type":"Plot"}},"id":"35a176c5-f1d1-42f0-8bc3-197c6587dd6c","type":"WheelZoomTool"},{"attributes":{},"id":"de3ada90-6131-4535-bdb2-15721ad9d2a0","type":"BasicTicker"},{"attributes":{},"id":"a17ec574-ebf9-41de-90c3-d03c1ee9b2f8","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"48d09e45-bdc4-4426-9fa9-8dd54a3090be","type":"DataRange1d"},{"attributes":{"plot":{"id":"001a0324-58df-4b60-ba3a-4a7815286074","subtype":"Figure","type":"Plot"}},"id":"5637a336-0fb3-4a88-a721-08f6e4428dcf","type":"SaveTool"},{"attributes":{"args":{"source":{"id":"87e69325-8d49-4542-bb76-e82c127b7bcd","type":"ColumnDataSource"}},"code":"\n    var data = source.data;\n    var f = cb_obj.value\n    x = data['x']\n    y = data['y']\n    for (i = 0; i < x.length; i++) {\n        y[i] = Math.pow(x[i], f)\n    }\n    source.change.emit();\n"},"id":"c3599728-b503-4081-9653-49ead8db86bf","type":"CustomJS"},{"attributes":{},"id":"2a9b5b70-0387-401e-af2e-61a03cab4c5c","type":"ToolEvents"},{"attributes":{"callback":null,"end":4,"js_property_callbacks":{"change:value":[{"id":"c3599728-b503-4081-9653-49ead8db86bf","type":"CustomJS"}]},"start":0.1,"title":"power","value":1},"id":"28e6bbb1-e946-4d26-b486-979e476d7d7c","type":"Slider"},{"attributes":{"plot":{"id":"001a0324-58df-4b60-ba3a-4a7815286074","subtype":"Figure","type":"Plot"}},"id":"58e29aa5-11bd-430e-b499-6a5980d8dfd0","type":"HelpTool"},{"attributes":{"children":[{"id":"f61fe93e-9830-459c-a531-b6fa6c123967","type":"WidgetBox"},{"id":"001a0324-58df-4b60-ba3a-4a7815286074","subtype":"Figure","type":"Plot"}]},"id":"8b30d4ce-8d66-4924-a006-9421a913fae5","type":"Column"},{"attributes":{"children":[{"id":"28e6bbb1-e946-4d26-b486-979e476d7d7c","type":"Slider"}]},"id":"f61fe93e-9830-459c-a531-b6fa6c123967","type":"WidgetBox"},{"attributes":{"plot":{"id":"001a0324-58df-4b60-ba3a-4a7815286074","subtype":"Figure","type":"Plot"},"ticker":{"id":"de3ada90-6131-4535-bdb2-15721ad9d2a0","type":"BasicTicker"}},"id":"7ce249c9-66d1-43a0-9c9c-1ebcfe111aba","type":"Grid"},{"attributes":{"formatter":{"id":"a17ec574-ebf9-41de-90c3-d03c1ee9b2f8","type":"BasicTickFormatter"},"plot":{"id":"001a0324-58df-4b60-ba3a-4a7815286074","subtype":"Figure","type":"Plot"},"ticker":{"id":"7dbc9b8f-2663-4ff8-a5 ...
