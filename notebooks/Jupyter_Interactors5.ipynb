# %%
import numpy as np

from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
output_notebook()
print("")
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="258088aa-c785-4d05-80c4-b77e46571c29">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.layouts import column
from bokeh.models import CustomJS, ColumnDataSource, Slider
from bokeh.plotting import Figure, output_file, show

output_file("js_on_change.html")

x = [x*0.005 for x in range(0, 200)]
y = x

source = ColumnDataSource(data=dict(x=x, y=y))

plot = Figure(plot_width=400, plot_height=400)
plot.line('x', 'y', source=source, line_width=3, line_alpha=0.6)

callback = CustomJS(args=dict(source=source), code="""
    var data = source.data;
    var f = cb_obj.value
    x = data['x']
    y = data['y']
    for (i = 0; i < x.length; i++) {
        y[i] = Math.pow(x[i], f)
    }
    source.change.emit();
""")

slider = Slider(start=0.1, end=4, value=1, step=.1, title="power")
slider.js_on_change('value', callback)

layout = column(slider, plot)

show(layout)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="26a9b52f-7664-4fe5-8cbf-81da5b153192"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("26a9b52f-7664-4fe5-8cbf-81da5b153192");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("26a9b52f-7664-4fe5-8cbf-81da5b153192");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '26a9b52f-7664-4fe5-8cbf-81da5b153192' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"116d16ef-4a0a-48ef-8c08-1402e31a03c7":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"baec3789-7707-4995-bb32-b10e99313dec","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"0468ad1a-eafb-4d0f-aa5a-ad370ad3bd24","type":"DataRange1d"},{"attributes":{},"id":"e6cf86d9-92e0-415c-9714-5631feff2a34","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"146d0145-4a20-403b-9ad6-aee1715dcd7b","subtype":"Figure","type":"Plot"}},"id":"a90c6cfb-3609-4c10-9a1f-d2e4035eb57a","type":"SaveTool"},{"attributes":{},"id":"44fabdc9-2f03-4836-ba0a-3b9d226d0d22","type":"LinearScale"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"68fd2516-ed96-4b4d-bf2d-45e9042e203a","type":"Line"},{"attributes":{"plot":{"id":"146d0145-4a20-403b-9ad6-aee1715dcd7b","subtype":"Figure","type":"Plot"}},"id":"30507f14-87a0-4a98-8624-83fc340a8bc5","type":"ResetTool"},{"attributes":{},"id":"f44b682e-4f0b-4282-a91a-e9e0659bc2ea","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"5b0c8af4-7f17-433e-af51-1cf9b293e885","type":"Title"},{"attributes":{"plot":{"id":"146d0145-4a20-403b-9ad6-aee1715dcd7b","subtype":"Figure","type":"Plot"}},"id":"b75b85a5-7d7e-4283-97f9-d9ea489739fe","type":"HelpTool"},{"attributes":{},"id":"fcf8bd92-0b08-40cf-850d-d981b624553d","type":"LinearScale"},{"attributes":{"formatter":{"id":"f44b682e-4f0b-4282-a91a-e9e0659bc2ea","type":"BasicTickFormatter"},"plot":{"id":"146d0145-4a20-403b-9ad6-aee1715dcd7b","subtype":"Figure","type":"Plot"},"ticker":{"id":"3d1445bd-d3a7-4733-8639-789ce42b67d3","type":"BasicTicker"}},"id":"f252678c-f376-4be2-800a-b3ef81becae3","type":"LinearAxis"},{"attributes":{"children":[{"id":"0bfd8578-5320-4d94-8c10-f6f1ed2dc42c","type":"WidgetBox"},{"id":"146d0145-4a20-403b-9ad6-aee1715dcd7b","subtype":"Figure","type":"Plot"}]},"id":"7543b86a-346d-4a0b-8f03-c50804e8e359","type":"Column"},{"attributes":{},"id":"3d1445bd-d3a7-4733-8639-789ce42b67d3","type":"BasicTicker"},{"attributes":{"plot":{"id":"146d0145-4a20-403b-9ad6-aee1715dcd7b","subtype":"Figure","type":"Plot"},"ticker":{"id":"3d1445bd-d3a7-4733-8639-789ce42b67d3","type":"BasicTicker"}},"id":"cb411ad6-5aae-4578-93eb-f835c98f15d8","type":"Grid"},{"attributes":{"below":[{"id":"f252678c-f376-4be2-800a-b3ef81becae3","type":"LinearAxis"}],"left":[{"id":"febc8225-aa6c-4f04-acb2-3386d102b3aa","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"f252678c-f376-4be2-800a-b3ef81becae3","type":"LinearAxis"},{"id":"cb411ad6-5aae-4578-93eb-f835c98f15d8","type":"Grid"},{"id":"febc8225-aa6c-4f04-acb2-3386d102b3aa","type":"LinearAxis"},{"id":"03b5dac1-6781-41b1-b1c8-c09beb315cc1","type":"Grid"},{"id":"baec3789-7707-4995-bb32-b10e99313dec","type":"BoxAnnotation"},{"id":"e2d2c0f0-0227-47c8-99d1-1caec197e4e5","type":"GlyphRenderer"}],"title":{"id":"5b0c8af4-7f17-433e-af51-1cf9b293e885","type":"Title"},"tool_events":{"id":"c736a34d-ea9d-4b72-9051-c323df4afcea","type":"ToolEvents"},"toolbar":{"id":"dd322464-0446-4c2b-8e2b-2155d4df6c9d","type":"Toolbar"},"x_range":{"id":"98647c1e-57c0-4486-b967-2bb6f2d1e140","type":"DataRange1d"},"x_scale":{"id":"44fabdc9-2f03-4836-ba0a-3b9d226d0d22","type":"LinearScale"},"y_range":{"id":"0468ad1a-eafb-4d0f-aa5a-ad370ad3bd24","type":"DataRange1d"},"y_scale":{"id":"fcf8bd92-0b08-40cf-850d-d981b624553d","type":"LinearScale"}},"id":"146d0145-4a20-403b-9ad6-aee1715dcd7b","subtype":"Figure","type":"Plot"},{"attributes":{"children":[{"id":"6e502c1a-6cb0-48f2-84a9-c97b3f920b2d","type":"Slider"}]},"id":"0bfd8578-5320-4d94-8c10-f6f1ed2dc42c","type":"WidgetBox"},{"attributes":{"data_source":{"id": ...

# %%
import numpy as np
from bokeh.io import show, output_file
from bokeh.plotting import figure
from bokeh import events
from bokeh.models import CustomJS, Div, Button
from bokeh.layouts import column, row

def display_event(div, attributes=[], style = 'float:left;clear:left;font_size=0.5pt'):
    "Build a suitable CustomJS to display the current event in the div model."
    return CustomJS(args=dict(div=div), code="""
        var attrs = %s; var args = [];
        for (var i=0; i<attrs.length; i++ ) {
            args.push(attrs[i] + '=' + Number(cb_obj[attrs[i]]).toFixed(2));
        }
        var line = "<span style=%r><b>" + cb_obj.event_name + "</b>(" + args.join(", ") + ")</span>\\n";
        var text = div.text.concat(line);
        var lines = text.split("\\n")
        if ( lines.length > 35 ) { lines.shift(); }
        div.text = lines.join("\\n");
    """ % (attributes, style))

x = np.random.random(size=4000) * 100
y = np.random.random(size=4000) * 100
radii = np.random.random(size=4000) * 1.5
colors = ["#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(50+2*x, 30+2*y)]

p = figure(tools="pan,wheel_zoom,zoom_in,zoom_out,reset")
p.scatter(x, y, radius=np.random.random(size=4000) * 1.5,
          fill_color=colors, fill_alpha=0.6, line_color=None)

div = Div(width=1000)
button = Button(label="Button", button_type="success")
layout = column(button, row(p, div))

## Events with no attributes
button.js_on_event(events.ButtonClick, display_event(div)) # Button click
p.js_on_event(events.LODStart, display_event(div))         # Start of LOD display
p.js_on_event(events.LODEnd, display_event(div))           # End of LOD display

## Events with attributes
point_attributes = ['x','y','sx','sy']                     # Point events
wheel_attributes = point_attributes+['delta']              # Mouse wheel event
pan_attributes = point_attributes + ['delta_x', 'delta_y'] # Pan event
pinch_attributes = point_attributes + ['scale']            # Pinch event

point_events =  [events.Tap, events.DoubleTap, events.Press,
                 events.MouseMove, events.MouseEnter, events.MouseLeave,
                 events.PanStart, events.PanEnd, events.PinchStart, events.PinchEnd]

for event in point_events:
    p.js_on_event(event,display_event(div, attributes=point_attributes))

p.js_on_event(events.MouseWheel, display_event(div,attributes=wheel_attributes))
p.js_on_event(events.Pan,        display_event(div, attributes=pan_attributes))
p.js_on_event(events.Pinch,      display_event(div, attributes=pinch_attributes))

output_file("js_events.html", title="JS Events Example")
show(layout)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="4eb1e072-169e-420a-a4dc-834d34cb4566"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("4eb1e072-169e-420a-a4dc-834d34cb4566");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4eb1e072-169e-420a-a4dc-834d34cb4566");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4eb1e072-169e-420a-a4dc-834d34cb4566' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"54ed6721-b0c2-440f-8500-8e123d7c4b52":{"roots":{"references":[{"attributes":{},"id":"5d80008d-f178-4ccc-945d-1ba75b545bb4","type":"BasicTicker"},{"attributes":{},"id":"bf36a93f-e8b7-4762-8184-237618a55a3d","type":"ToolEvents"},{"attributes":{"formatter":{"id":"7cd8b6f3-77eb-428f-ae04-3df3e9fb4d90","type":"BasicTickFormatter"},"plot":{"id":"75a348e0-c0d0-4840-b8d6-40774aa8454d","subtype":"Figure","type":"Plot"},"ticker":{"id":"8dabce87-d4e9-417b-af95-2f4144c8b12f","type":"BasicTicker"}},"id":"4a762c6b-a55f-4367-87b1-f96a3edea097","type":"LinearAxis"},{"attributes":{},"id":"8dabce87-d4e9-417b-af95-2f4144c8b12f","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"75a348e0-c0d0-4840-b8d6-40774aa8454d","subtype":"Figure","type":"Plot"},"ticker":{"id":"8dabce87-d4e9-417b-af95-2f4144c8b12f","type":"BasicTicker"}},"id":"a791ad98-624f-4251-bea1-16237ebdac68","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"field":"radius","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"63f3bc28-d553-4dc7-ada1-098d7b94c179","type":"Circle"},{"attributes":{"args":{"div":{"id":"d46ca108-5e17-41ed-9400-0880244bee50","type":"Div"}},"code":"\n        var attrs = []; var args = [];\n        for (var i=0; i<attrs.length; i++ ) {\n            args.push(attrs[i] + '=' + Number(cb_obj[attrs[i]]).toFixed(2));\n        }\n        var line = \"<span style='float:left;clear:left;font_size=0.5pt'><b>\" + cb_obj.event_name + \"</b>(\" + args.join(\", \") + \")</span>\\n\";\n        var text = div.text.concat(line);\n        var lines = text.split(\"\\n\")\n        if ( lines.length > 35 ) { lines.shift(); }\n        div.text = lines.join(\"\\n\");\n    "},"id":"f6b30efd-e218-4476-9f93-1acb7d650228","type":"CustomJS"},{"attributes":{},"id":"7cd8b6f3-77eb-428f-ae04-3df3e9fb4d90","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"75a348e0-c0d0-4840-b8d6-40774aa8454d","subtype":"Figure","type":"Plot"}},"id":"9edd3e5f-996c-4ed3-a835-f27e9a303dee","type":"PanTool"},{"attributes":{"plot":null,"text":""},"id":"8fd04024-afd1-4e4e-a54a-26f16bd23099","type":"Title"},{"attributes":{"plot":{"id":"75a348e0-c0d0-4840-b8d6-40774aa8454d","subtype":"Figure","type":"Plot"}},"id":"e0204a1a-3268-4e71-b039-3d0f08b6b60c","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"75a348e0-c0d0-4840-b8d6-40774aa8454d","subtype":"Figure","type":"Plot"}},"id":"69a4d005-43ef-45ed-a29f-498d89430df1","type":"ZoomInTool"},{"attributes":{"plot":{"id":"75a348e0-c0d0-4840-b8d6-40774aa8454d","subtype":"Figure","type":"Plot"}},"id":"769ca035-b919-4ca6-b81b-ff54291dbb03","type":"ZoomOutTool"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"field":"fill_color"},"line_color":{"value":null},"radius":{"field":"radius","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5e87f394-f180-403f-adab-9459a99a520f","type":"Circle"},{"attributes":{"plot":{"id":"75a348e0-c0d0-4840-b8d6-40774aa8454d","subtype":"Figure","type":"Plot"}},"id":"77d8f429-df50-4dc9-bd18-494d27b610d9","type":"ResetTool"},{"attributes":{"data_source":{"id":"a7baaff9-dfb9-4c2d-921d-ad802d7111a8","type":"ColumnDataSource"},"glyph":{"id":"5e87f394-f180-403f-adab-9459a99a520f","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"63f3bc28-d553-4dc7-ada1-098d7b94c179","type":"Circle"},"selection_glyph":null},"id":"166f0337-b3cf-4b10-94fe-446eb7684434","type":"GlyphRenderer"},{"attributes":{},"id":"9fc56b8a-d7c9-41dd-a75a-0a6b904cf8b7","type":"BasicTickFormatter"},{"attributes":{"args":{"div":{"id":"d46ca108-5e17-41ed-9400-0880244bee50","type":"Div"}},"code":"\n        var attrs = []; var args = [];\n        for (var i=0; i<attrs.length; i++ ) {\n            args.push(attrs[i] + '=' + Number(cb_obj[attrs[i]]).toFixed(2));\n        }\n        var line = \"<span style='float:left;clear:left;font_size=0.5pt'><b>\" + cb_obj.event_name + \"</b>(\"  ...

# %%
# %%html
# <script>
#     var code_show=true; //true -> hide code at first
#
#     function code_toggle() {
#         $('div.prompt').hide(); // always hide prompt
#
#         if (code_show){
#             $('div.input').hide();
#         } else {
#             $('div.input').show();
#         }
#         code_show = !code_show
#     }
#     $( document ).ready(code_toggle);
# </script>
# <a href="javascript:code_toggle()">[Toggle Code]</a>
# Out:
# <script>
#     var code_show=true; //true -> hide code at first
#
#     function code_toggle() {
#         $('div.prompt').hide(); // always hide prompt
#
#         if (code_show){
#             $('div.input').hide();
#         } else {
#             $('div.input').show();
#         }
#         code_show = !code_show
#     }
#     $( document ).ready(code_toggle);
# </script>
# <a href="javascript:code_toggle()">[Toggle Code]</a>
