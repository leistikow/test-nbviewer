# %%
import numpy as np

from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
output_notebook()
print("")
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="469e0aeb-a8da-4b3e-9167-b1782bc869df">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.layouts import column
from bokeh.models import CustomJS, ColumnDataSource, Slider
from bokeh.plotting import Figure, output_file, show

output_file("js_on_change.html")

x = [x*0.005 for x in range(0, 200)]
y = x

source = ColumnDataSource(data=dict(x=x, y=y))

plot = Figure(plot_width=400, plot_height=400)
plot.line('x', 'y', source=source, line_width=3, line_alpha=0.6)

callback = CustomJS(args=dict(source=source), code="""
    var data = source.data;
    var f = cb_obj.value
    x = data['x']
    y = data['y']
    for (i = 0; i < x.length; i++) {
        y[i] = Math.pow(x[i], f)
    }
    source.change.emit();
""")

slider = Slider(start=0.1, end=4, value=1, step=.1, title="power")
slider.js_on_change('value', callback)

layout = column(slider, plot)

show(layout)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="32608a28-8b32-44c7-a150-20b0876bf90e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("32608a28-8b32-44c7-a150-20b0876bf90e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("32608a28-8b32-44c7-a150-20b0876bf90e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '32608a28-8b32-44c7-a150-20b0876bf90e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"519259fc-2743-4db3-adec-a8ad25aec064":{"roots":{"references":[{"attributes":{"formatter":{"id":"6b5bee72-4b1e-4ece-99ce-c5c3c3697ff0","type":"BasicTickFormatter"},"plot":{"id":"f4d18734-f88f-46b5-8b82-12ea24278293","subtype":"Figure","type":"Plot"},"ticker":{"id":"0fdad3c7-ed95-4c2a-a431-fc639986ab06","type":"BasicTicker"}},"id":"ee318cb9-6e25-4b2d-a1e1-e9b0d50b61a8","type":"LinearAxis"},{"attributes":{},"id":"0fdad3c7-ed95-4c2a-a431-fc639986ab06","type":"BasicTicker"},{"attributes":{"children":[{"id":"0e230feb-506e-4354-94ff-f4363119106c","type":"WidgetBox"},{"id":"f4d18734-f88f-46b5-8b82-12ea24278293","subtype":"Figure","type":"Plot"}]},"id":"a5250f35-9a58-467a-a294-a947726fa978","type":"Column"},{"attributes":{"plot":{"id":"f4d18734-f88f-46b5-8b82-12ea24278293","subtype":"Figure","type":"Plot"},"ticker":{"id":"0fdad3c7-ed95-4c2a-a431-fc639986ab06","type":"BasicTicker"}},"id":"5ef52e39-e944-47d8-a379-51f9c4de6ded","type":"Grid"},{"attributes":{"line_alpha":{"value":0.6},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"77723213-30be-479a-b526-b4851db41d9b","type":"Line"},{"attributes":{"children":[{"id":"4297d61f-abc5-4898-b81f-75b1a088f7a1","type":"Slider"}]},"id":"0e230feb-506e-4354-94ff-f4363119106c","type":"WidgetBox"},{"attributes":{"formatter":{"id":"31e88f0e-4aab-4902-a48f-4e5d8f7f07ca","type":"BasicTickFormatter"},"plot":{"id":"f4d18734-f88f-46b5-8b82-12ea24278293","subtype":"Figure","type":"Plot"},"ticker":{"id":"d4052081-2805-438e-ab6a-c6cc85ad8d00","type":"BasicTicker"}},"id":"44f7ff49-ca8f-45d1-9bb1-ba5e85e27e02","type":"LinearAxis"},{"attributes":{"callback":null,"end":4,"js_property_callbacks":{"change:value":[{"id":"21e1736c-d35d-4cc6-a5ef-12e15f696b93","type":"CustomJS"}]},"start":0.1,"title":"power","value":1},"id":"4297d61f-abc5-4898-b81f-75b1a088f7a1","type":"Slider"},{"attributes":{},"id":"d4052081-2805-438e-ab6a-c6cc85ad8d00","type":"BasicTicker"},{"attributes":{"below":[{"id":"ee318cb9-6e25-4b2d-a1e1-e9b0d50b61a8","type":"LinearAxis"}],"left":[{"id":"44f7ff49-ca8f-45d1-9bb1-ba5e85e27e02","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"ee318cb9-6e25-4b2d-a1e1-e9b0d50b61a8","type":"LinearAxis"},{"id":"5ef52e39-e944-47d8-a379-51f9c4de6ded","type":"Grid"},{"id":"44f7ff49-ca8f-45d1-9bb1-ba5e85e27e02","type":"LinearAxis"},{"id":"5347f1aa-30f2-42d9-822b-aa7c8978afa2","type":"Grid"},{"id":"762d7acb-264a-4baa-aa0b-98d60234018a","type":"BoxAnnotation"},{"id":"6d7a7357-a8cb-4759-9e84-4d1d99e23f0d","type":"GlyphRenderer"}],"title":{"id":"24e26170-375c-4669-a534-b5fcb734c850","type":"Title"},"tool_events":{"id":"bd5c9d92-ed78-4add-88ca-aa9bcbe13fab","type":"ToolEvents"},"toolbar":{"id":"b7dab494-10f0-4805-80e0-8d109af4f93e","type":"Toolbar"},"x_range":{"id":"f1f5ef4a-1a02-4727-8560-0cae8fc45938","type":"DataRange1d"},"x_scale":{"id":"faa5dd42-1521-460c-a2a3-c97c9064683a","type":"LinearScale"},"y_range":{"id":"a002981a-9fd0-40f5-8aba-2eb40aed847e","type":"DataRange1d"},"y_scale":{"id":"c7868f9b-8c65-4021-a48c-a8b0f7c0d31f","type":"LinearScale"}},"id":"f4d18734-f88f-46b5-8b82-12ea24278293","subtype":"Figure","type":"Plot"},{"attributes":{"dimension":1,"plot":{"id":"f4d18734-f88f-46b5-8b82-12ea24278293","subtype":"Figure","type":"Plot"},"ticker":{"id":"d4052081-2805-438e-ab6a-c6cc85ad8d00","type":"BasicTicker"}},"id":"5347f1aa-30f2-42d9-822b-aa7c8978afa2","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.0,0.005,0.01,0.015,0.02,0.025,0.03,0.035,0.04,0.045,0.05,0.055,0.06,0.065,0.07,0.075,0.08,0.085,0.09,0.095,0.1,0.105,0.11,0.115,0.12,0.125,0.13,0.135,0.14,0.145,0.15,0.155,0.16,0.165,0.17,0.17500000000000002,0.18,0.185,0.19,0.195,0.2,0.20500000000000002,0.21,0.215,0.22,0.225,0.23,0.23500000000000001,0.24,0.245,0.25,0.255,0.26,0.265,0.27,0.275,0.28,0.28500000000000003,0.29,0.295,0.3,0.305,0.31,0.315,0.32,0.325,0.33,0.335,0.34,0.34500000000000003,0.35000000000000003,0.355,0.36, ...

# %%
import numpy as np
from bokeh.io import show, output_file
from bokeh.plotting import figure
from bokeh import events
from bokeh.models import CustomJS, Div, Button
from bokeh.layouts import column, row

def display_event(div, attributes=[], style = 'float:left;clear:left;font_size=0.5pt'):
    "Build a suitable CustomJS to display the current event in the div model."
    return CustomJS(args=dict(div=div), code="""
        var attrs = %s; var args = [];
        for (var i=0; i<attrs.length; i++ ) {
            args.push(attrs[i] + '=' + Number(cb_obj[attrs[i]]).toFixed(2));
        }
        var line = "<span style=%r><b>" + cb_obj.event_name + "</b>(" + args.join(", ") + ")</span>\\n";
        var text = div.text.concat(line);
        var lines = text.split("\\n")
        if ( lines.length > 35 ) { lines.shift(); }
        div.text = lines.join("\\n");
    """ % (attributes, style))

x = np.random.random(size=4000) * 100
y = np.random.random(size=4000) * 100
radii = np.random.random(size=4000) * 1.5
colors = ["#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(50+2*x, 30+2*y)]

p = figure(tools="pan,wheel_zoom,zoom_in,zoom_out,reset")
p.scatter(x, y, radius=np.random.random(size=4000) * 1.5,
          fill_color=colors, fill_alpha=0.6, line_color=None)

div = Div(width=1000)
button = Button(label="Button", button_type="success")
layout = column(button, row(p, div))

## Events with no attributes
button.js_on_event(events.ButtonClick, display_event(div)) # Button click
p.js_on_event(events.LODStart, display_event(div))         # Start of LOD display
p.js_on_event(events.LODEnd, display_event(div))           # End of LOD display

## Events with attributes
point_attributes = ['x','y','sx','sy']                     # Point events
wheel_attributes = point_attributes+['delta']              # Mouse wheel event
pan_attributes = point_attributes + ['delta_x', 'delta_y'] # Pan event
pinch_attributes = point_attributes + ['scale']            # Pinch event

point_events =  [events.Tap, events.DoubleTap, events.Press,
                 events.MouseMove, events.MouseEnter, events.MouseLeave,
                 events.PanStart, events.PanEnd, events.PinchStart, events.PinchEnd]

for event in point_events:
    p.js_on_event(event,display_event(div, attributes=point_attributes))

p.js_on_event(events.MouseWheel, display_event(div,attributes=wheel_attributes))
p.js_on_event(events.Pan,        display_event(div, attributes=pan_attributes))
p.js_on_event(events.Pinch,      display_event(div, attributes=pinch_attributes))

output_file("js_events.html", title="JS Events Example")
show(layout)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0d5cc04f-9e38-4f3c-8885-7bbca780712e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0d5cc04f-9e38-4f3c-8885-7bbca780712e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0d5cc04f-9e38-4f3c-8885-7bbca780712e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0d5cc04f-9e38-4f3c-8885-7bbca780712e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1b8f83b4-e92e-43c4-ab4f-a1ceb45ace54":{"roots":{"references":[{"attributes":{},"id":"7c5f4a2e-85aa-42f0-ba64-92b06d4015ab","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"99f78857-eca3-494f-b013-172a93f6790b","subtype":"Figure","type":"Plot"},"ticker":{"id":"82c3d517-8dff-415d-9119-b93b839a7363","type":"BasicTicker"}},"id":"f98851d8-938e-491c-aa51-10d361372c68","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"field":"radius","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9101c5d8-ea65-41cd-8feb-d9cdd1f68434","type":"Circle"},{"attributes":{"args":{"div":{"id":"8aacb59b-b4aa-4dd2-9c7d-9e7716756b55","type":"Div"}},"code":"\n        var attrs = []; var args = [];\n        for (var i=0; i<attrs.length; i++ ) {\n            args.push(attrs[i] + '=' + Number(cb_obj[attrs[i]]).toFixed(2));\n        }\n        var line = \"<span style='float:left;clear:left;font_size=0.5pt'><b>\" + cb_obj.event_name + \"</b>(\" + args.join(\", \") + \")</span>\\n\";\n        var text = div.text.concat(line);\n        var lines = text.split(\"\\n\")\n        if ( lines.length > 35 ) { lines.shift(); }\n        div.text = lines.join(\"\\n\");\n    "},"id":"b95b15ce-0112-4020-8558-ba8f66247467","type":"CustomJS"},{"attributes":{},"id":"8952a24c-311c-471b-bf09-29de3e98bc0f","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"99f78857-eca3-494f-b013-172a93f6790b","subtype":"Figure","type":"Plot"}},"id":"9a82d4b2-a525-4bba-b6a7-fdfca7522be9","type":"PanTool"},{"attributes":{"plot":null,"text":""},"id":"ca6279ec-c8af-463b-abed-b76c4a5f068d","type":"Title"},{"attributes":{"plot":{"id":"99f78857-eca3-494f-b013-172a93f6790b","subtype":"Figure","type":"Plot"}},"id":"858222f7-645a-4ecc-a691-a2153c5418cd","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"99f78857-eca3-494f-b013-172a93f6790b","subtype":"Figure","type":"Plot"}},"id":"c3cb1fc5-2b3d-439d-9fc8-d2afe5c9d05d","type":"ZoomInTool"},{"attributes":{"plot":{"id":"99f78857-eca3-494f-b013-172a93f6790b","subtype":"Figure","type":"Plot"}},"id":"852f50ca-d679-4667-9b6c-fffc383ad316","type":"ZoomOutTool"},{"attributes":{"plot":{"id":"99f78857-eca3-494f-b013-172a93f6790b","subtype":"Figure","type":"Plot"}},"id":"7194bbbe-15e3-420e-8507-7de040fa29ee","type":"ResetTool"},{"attributes":{"data_source":{"id":"dc91acf0-6581-4289-85f1-7f7be30a1848","type":"ColumnDataSource"},"glyph":{"id":"34760a6c-057f-40a5-856b-10040dd5eb97","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"9101c5d8-ea65-41cd-8feb-d9cdd1f68434","type":"Circle"},"selection_glyph":null},"id":"18b18975-c4f1-4efa-892b-414669ba1523","type":"GlyphRenderer"},{"attributes":{},"id":"c5f5ee80-f37e-4834-bc76-f4bd1a9376e2","type":"BasicTickFormatter"},{"attributes":{"button_type":"success","callback":null,"icon":null,"js_event_callbacks":{"button_click":[{"id":"b95b15ce-0112-4020-8558-ba8f66247467","type":"CustomJS"}]}},"id":"88946cc6-8d46-4976-9f3c-ac41a7d0d51f","type":"Button"},{"attributes":{"args":{"div":{"id":"8aacb59b-b4aa-4dd2-9c7d-9e7716756b55","type":"Div"}},"code":"\n        var attrs = []; var args = [];\n        for (var i=0; i<attrs.length; i++ ) {\n            args.push(attrs[i] + '=' + Number(cb_obj[attrs[i]]).toFixed(2));\n        }\n        var line = \"<span style='float:left;clear:left;font_size=0.5pt'><b>\" + cb_obj.event_name + \"</b>(\" + args.join(\", \") + \")</span>\\n\";\n        var text = div.text.concat(line);\n        var lines = text.split(\"\\n\")\n        if ( lines.length > 35 ) { lines.shift(); }\n        div.text = lines.join(\"\\n\");\n    "},"id":"2359df2c-d3a6-4526-b193-0c5b1b1c40a8","type":"CustomJS"},{"attributes":{"args":{"div":{"id":"8aacb59b-b4aa-4dd2-9c7d-9e7716756b55","type":"Div"}},"code":"\n        var attrs = []; var args = [];\n        for (var i=0; i<attrs.length; i++ ) {\n            args.push(attrs[i] + '= ...

# %%
# %%html
# <script>
#     var code_show=true; //true -> hide code at first
#
#     function code_toggle() {
#         $('div.prompt').hide(); // always hide prompt
#
#         if (code_show){
#             $('div.input').hide();
#         } else {
#             $('div.input').show();
#         }
#         code_show = !code_show
#     }
#     $( document ).ready(code_toggle);
# </script>
# <a href="javascript:code_toggle()">[Toggle Code]</a>
# Out:
# <script>
#     var code_show=true; //true -> hide code at first
#
#     function code_toggle() {
#         $('div.prompt').hide(); // always hide prompt
#
#         if (code_show){
#             $('div.input').hide();
#         } else {
#             $('div.input').show();
#         }
#         code_show = !code_show
#     }
#     $( document ).ready(code_toggle);
# </script>
# <a href="javascript:code_toggle()">[Toggle Code]</a>
